# %%
import geopandas as gpd
import pandas as pd
from helper import *

# %%
# read in species count df
df = pd.read_csv('./species_count.csv')
# convert to geodataframe
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.lon, df.lat))[['species_count','geometry']]

ord = output_geotiff(gdf,"./species_count.tif",3000)

# %%
ord.species_count.plot()
